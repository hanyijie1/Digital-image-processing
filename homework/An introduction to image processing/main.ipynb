# %% [markdown]
# # An introduction to image processing
#
# matlab online 里面的图片不给导出，嫌麻烦就随便用了4张图片。 外加一张判断是否是收据的晴天娃娃。
#
# ## module 2: Processing images in matlab

# %%
from src import Module2

module2_info = Module2()
module2_info.module2_section1_part1()

# %%
module2_info.module2_section2_part2()
# Out:
# The shape of red matrix is 604*403, and max bin is 255, min bin is 32

# %%
module2_info.module2_section2_part3()
# Out:
# The shape of red matrix is 579*385.

# %%
module2_info.module2_section3_part1()

# %% [markdown]
# ## module 3: split image

# %%
from src import Module3
module3_info = Module3()
module3_info.module3_section1_part1()
# Out:
# We have plot the hist image of case 1 on module 2 section 3 part 1, we won't go into details here.

# %%
module3_info.module3_section1_part2()
# Out:
# python好像不需要INV

# %%
module3_info.module3_section2_part1()

# %% [markdown]
# ## Module 4: Pretreatment and post-treatment methods.

# %%
from src import Module4
module4_info = Module4()
module4_info.module3_section1_part2()
module4_info.module4_section1_part2()
# Out:
# python好像不需要INV
# 这到底是清楚还是模糊了就很难说了。

# %%
module4_info.module4_section2_part3()

# %%
module4_info.module4_section2_part4()

# %% [markdown]
# ## Module: sorting and batch processing

# %%
from src import Module5
module5_info = Module5()
module5_info.module5_section1_part1()

# %% [markdown]
# 关于类似于imageDatastore的函数python有很多，比如dask中的delay-compute()。但是就我经验来看此类函数因透明度一般是不如直接调用png文件或者类似的数据存储文件(h5, csv, dat等)中，甚至直接放在swap里速度也远快于dask中。因此此处不予类比处理。
#
# 而且此类操作矛盾之处在于不追求并行化的时候这一点内存消耗是可有可无的，追求并行化的时候显存或内存消耗又是必须的。
#
# 总之，与其内存优化，不如购买显卡。

# %%
module5_info.module5_section1_part34()
# Out:
# To sum up, the compared possibilities images are receipts:
# [0.77586207 1.         0.34482759 0.0862069  0.        ]
# the possibility sequence of is_receipt images display:
